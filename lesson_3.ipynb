# %% [markdown]
# Lesson_3 Системы управления базами данных MongoDB и SQLite в Python

# %% [markdown]
# Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, записывающую собранные вакансии в созданную БД.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from lesson3class import Les3Class
from pprint import pprint

# %%
vacancy_db = Les3Class('vacancy', 'vacancy_db')

# %%
find_vacancy = 'Python'

# %%
vacancy_db.start_parsers(find_vacancy)

# %% [markdown]
# Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы.

# %%
vacancy_db.find_salary(300000)
# Out:
# {'_id': ObjectId('60a13d3e9261013aec15ddca'),
#  'city': 'Москва',
#  'link': 'https://hh.ru/vacancy/44050464?query=Python',
#  'name': 'Senior Backend-разработчик (Python)',
#  'salary_currency': 'руб.',
#  'salary_max': 320000,
#  'salary_min': 200000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('60a13d3f9261013aec15dddd'),
#  'city': 'Москва',
#  'link': 'https://hh.ru/vacancy/43974138?query=Python',
#  'name': 'Python Developer (USD Salary, Remote)',
#  'salary_currency': 'руб.',
#  'salary_max': 350000,
#  'salary_min': 250000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('60a13d3f9261013aec15ddf1'),
#  'city': 'Москва',
#  'link': 'https://hh.ru/vacancy/44385969?query=Python',
#  'name': 'Data Scientist (компьютерное зрение)',
#  'salary_currency': 'руб.',
#  'salary_max': 400000,
#  'salary_min': 70000,
#  'site': 'hh.ru'}
# {'_id': ObjectId('60a13d409261013aec15ddfc'),
#  'city': 'Санкт-Петербург',
#  'link': 'https://hh.ru/vacancy/44408240?query=Python',
# ...

# %% [markdown]
#  Написать функцию, которая будет добавлять в вашу базу данных только новые вакансии с сайта.

# %% [markdown]
# Реализовано в Les3Class

# %% [markdown]
#     def unique(self, name_field, list_values):
#         return bool (self.collection.find_one({name_field: {'$in': [list_values]}}))

# %% [markdown]
# ...................................................................................................
# ...................................................................................................
# ...................................................................................................

# %% [markdown]
#                     if self.unique('link', vacancy['link']):
#                         self.collection.update_one({'link': vacancy['link']}, {'$set': vacancy})
#                     else:
#                         self.collection.insert_one(vacancy)
